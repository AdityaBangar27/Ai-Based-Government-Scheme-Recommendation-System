# %% [markdown]
# # Dataset Generation Notebook
#
# Use this notebook to rebuild the recommendation dataset deterministically with rule-based scheme eligibility and validate output files.

# %%
from rebuild_datasets import build_datasets, validate_dataset

users_df, training_df = build_datasets()
report_lines = validate_dataset(users_df, training_df)

print('=== Dataset generation complete ===')
print(f'users.csv records: {len(users_df):,}')
print(f'training_dataset.csv records: {len(training_df):,}')
print()
print('--- REPORT ---')
print('
'.join(report_lines))
